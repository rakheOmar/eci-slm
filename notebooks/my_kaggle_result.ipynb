# %% [markdown]
# # ECI-SLM Setup + Train (pip)
#
# This notebook does exactly:
# 1. `git clone`
# 2. `cd` + `git pull`
# 3. install dependencies with **pip** (no uv)
# 4. start training

# %%
from pathlib import Path
import os
import subprocess
import sys

GITHUB_USER = "rakheOmar"
REPO_SLUG = "rakheOmar/eci-slm"
GITHUB_TOKEN = os.getenv("GITHUB_TOKEN", "GITHUB_TOKEN")
BRANCH = "main"
REPO_DIR = Path('/kaggle/working/eci-slm')

if GITHUB_TOKEN == "<YOUR_GITHUB_TOKEN>":
    REPO_URL = f"https://github.com/{REPO_SLUG}.git"
    print("Using unauthenticated clone URL. Set GITHUB_TOKEN for private repo access.")
else:
    REPO_URL = f"https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{REPO_SLUG}.git"

print(f"Repo: {REPO_SLUG}")
print(f"Repo dir: {REPO_DIR}")
# Out:
# Repo: rakheOmar/eci-slm
# Repo dir: /kaggle/working/eci-slm

# %%
if not REPO_DIR.exists():
    subprocess.run(["git", "clone", REPO_URL, str(REPO_DIR)], check=True)
else:
    print(f"Repo already exists: {REPO_DIR}")

os.chdir(REPO_DIR)
print(f"Current dir: {Path.cwd()}")

subprocess.run(["git", "fetch", "origin"], check=True)
subprocess.run(["git", "checkout", BRANCH], check=True)
subprocess.run(["git", "pull", "--ff-only", "origin", BRANCH], check=True)
# Out:
# Repo already exists: /kaggle/working/eci-slm
# Current dir: /kaggle/working/eci-slm
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# Already up to date.
# From https://github.com/rakheOmar/eci-slm
#  * branch            main       -> FETCH_HEAD
# CompletedProcess(args=['git', 'pull', '--ff-only', 'origin', 'main'], returncode=0)

# %%
# !python -m pip install -U pip setuptools wheel --no-cache-dir --prefer-binary --progress-bar off && (python -m pip install -e . --no-cache-dir --prefer-binary --progress-bar off || python -m pip install datasets>=4.8.4 python-dotenv>=1.2.2 sentencepiece>=0.2.1 tiktoken>=0.12.0 --no-cache-dir --prefer-binary --progress-bar off) && python -m pip install ipykernel ruff --no-cache-dir --prefer-binary --progress-bar off
# Out:
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
# Obtaining file:///kaggle/working/eci-slm
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for eci-slm (pyproject.toml) ... done
#   Created wheel for eci-slm: filename=eci_slm-0.1.0-0.editable-py3-none-any.whl size=1356 sha256=15295a80ad530b29e15a2e99be88e349b5b3a29ae1cf7a69ac857fb16367d016
#   Stored in directory: /tmp/pip-ephem-wheel-cache-akg7izfr/wheels/3b/9f/71/1e661707ed3d80471c19cee27860f56c61a7474f980c416175
# Successfully built eci-slm
# ...

# %%
# !python main.py \
  --mode prepare_and_train \
  --stage pretrain \
  --rebuild_bins \
  --english_ratio 0.93 \
  --strategy auto \
  --precision fp32 \
  --checkpoint_dir /kaggle/working/checkpoints \
  --keep_last_n 5 \
  --resume \
  --max_steps 12000 \
  --batch_size 16 \
  --grad_accum_steps 2 \
  --learning_rate 2.5e-4 \
  --warmup_steps 1200 \
  --eval_interval 100 \
  --save_interval 100 \
  --log_interval 20
# Out:
# Training tokenizer with vocab size: 8000
# Input: /kaggle/working/eci-slm/data/combined_train.txt
# Output: /kaggle/working/eci-slm/artifact/eci_slm_tokenizer.model
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /kaggle/working/eci-slm/data/combined_train.txt
#   input_format:
#   model_prefix: /kaggle/working/eci-slm/artifact/eci_slm_tokenizer
#   model_type: BPE
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
# ...

# %%
# %cd /kaggle/input/datasets/omarrakhe/12k-run-ouptut/eci-slm
# !python main.py \
  --mode prepare_and_train \
  --stage sft \
  --rebuild_bins \
  --sft_source_dirs data/instruct \
  --sft_bin_dir /kaggle/working/artifact_sft \
  --init_checkpoint_dir /kaggle/input/datasets/omarrakhe/12k-run-ouptut/checkpoints \
  --init_step 10600 \
  --checkpoint_dir /kaggle/working/checkpoints_sft \
  --keep_last_n 5 \
  --strategy auto \
  --precision mixed_fp16 \
  --max_steps 2000 \
  --batch_size 16 \
  --grad_accum_steps 2 \
  --sft_learning_rate 1e-5 \
  --sft_warmup_steps 200 \
  --eval_interval 50 \
  --save_interval 50 \
  --log_interval 20
# Out:
# /kaggle/input/datasets/omarrakhe/12k-run-ouptut/eci-slm
# 2026-03-29 08:47:39.264217: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774774059.645353     102 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774774059.751031     102 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774774060.737444     102 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import tensorflow as tf
from src.tokenizer import Tokenizer
from src.slm import ECISLM, SLMConfig
from src.checkpoint import load_checkpoint
from pathlib import Path
# ---- paths (edit if needed) ----
REPO_ROOT = Path.cwd()
if not (REPO_ROOT / "main.py").exists():
    candidate = Path("/kaggle/working/eci-slm")
    if (candidate / "main.py").exists():
        REPO_ROOT = candidate
CKPT_DIR = Path("/kaggle/working/checkpoints_sft")
if not CKPT_DIR.exists():
    CKPT_DIR = Path("/kaggle/working/checkpoints")
TOKENIZER_PATH = REPO_ROOT / "artifact" / "eci_slm_tokenizer.model"
STEP = int((CKPT_DIR / "best_step.txt").read_text().strip())
PROMPT = "Can nomination papers be sent by email?"
MAX_TOKENS = 80
# ---- load ----
tokenizer = Tokenizer(TOKENIZER_PATH)
cfg = SLMConfig(
    vocab_size=tokenizer.vocab_size,
    block_size=256,
    n_layer=6,
    n_head=6,
    n_kv_head=2,
    n_embd=384,
    tie_embeddings=True,
)
model = ECISLM(cfg)
_ = model(tf.zeros((1, cfg.block_size), dtype=tf.int32))
_ = load_checkpoint(checkpoint_dir=CKPT_DIR, step=STEP, model=model, optimizer=None)
print(f"Loaded step {STEP} from {CKPT_DIR}\n")
def run(prompt, temperature, top_k):
    full = f"User: {prompt}\nAssistant: "
    input_ids = tokenizer.encode(full)
    x = tf.constant([input_ids], dtype=tf.int32)
    y = model.generate(
        idx=x,
        max_new_tokens=MAX_TOKENS,
        temperature=temperature,
        top_k=top_k,
    ).numpy()[0].tolist()
    text = tokenizer.decode(y[len(input_ids):])
    for marker in ["\nUser:", "<END>"]:
        pos = text.find(marker)
        if pos != -1:
            text = text[:pos]
    return text.strip()
# ---- sweep configs ----
configs = [
    # Deterministic / debugging
    (0.1, 1),
    (0.2, 1),
    (0.3, 1),

    # Low diversity (reduce repetition slightly)
    (0.3, 5),
    (0.4, 5),
    (0.4, 10),

    # Balanced zone (MOST IMPORTANT)
    (0.5, 10),
    (0.5, 20),
    (0.55, 20),
    (0.6, 20),
    (0.6, 30),
    (0.65, 30),
    (0.7, 30),

    # Exploration sweet spot
    (0.7, 40),
    (0.75, 40),
    (0.8, 40),

    # High diversity
    (0.7, 50),
    (0.8, 50),
    (0.9, 50),

    # Stress test / chaos
    (1.0, 50),
    (1.1, 50),
]
for temp, top_k in configs:
    out = run(PROMPT, temp, top_k)
    print(f"[temp={temp}, top_k={top_k}]")
    print(out)
    print("-" * 60)
# Out:
# Loaded tokenizer: /kaggle/input/datasets/omarrakhe/12k-run-ouptut/eci-slm/artifact/eci_slm_tokenizer.model
# Loaded step 1650 from /kaggle/working/checkpoints_sft
#
# [temp=0.1, top_k=1]
# No. The nomination paper shall be made by the Returning Officer. The nomination paper shall be made in the nomination paper. The nomination paper shall be made in the nomination paper. The nomination paper shall be made in the nomination paper. The nomination paper shall be made in the nomination paper. The nomination paper shall be made in the nomination paper. The nomination paper shall be made
# ------------------------------------------------------------
# [temp=0.2, top_k=1]
# ...

# %%
import tensorflow as tf
from src.tokenizer import Tokenizer
from src.slm import ECISLM, SLMConfig
from src.checkpoint import load_checkpoint
from pathlib import Path

# ---- paths ----
REPO_ROOT = Path.cwd()
if not (REPO_ROOT / "main.py").exists():
    candidate = Path("/kaggle/working/eci-slm")
    if (candidate / "main.py").exists():
        REPO_ROOT = candidate

CKPT_DIR = Path("/kaggle/working/checkpoints_sft")
if not CKPT_DIR.exists():
    CKPT_DIR = Path("/kaggle/working/checkpoints")

TOKENIZER_PATH = REPO_ROOT / "artifact" / "eci_slm_tokenizer.model"
STEP = int((CKPT_DIR / "best_step.txt").read_text().strip())

MAX_TOKENS = 80

# ---- BEST CONFIG ----
TEMPERATURE = 0.5
TOP_K = 10

# ---- PROMPTS ----
QA_PROMPTS = [
    '''
    User: Can nomination papers be sent by email?
Assistant: No. Nomination papers must be submitted physically to the Returning Officer.

User: Who can submit a nomination paper?
Assistant:'''
    "Can nomination papers be sent by email?",
    "Who can submit a nomination paper?",
    "What happens if nomination papers are incomplete?",
]

CONTINUATION_PROMPTS = [
    "Nomination papers must be filed",
    "The Returning Officer shall",
    "If a candidate fails to submit required documents",
]

# ---- load ----
tokenizer = Tokenizer(TOKENIZER_PATH)

cfg = SLMConfig(
    vocab_size=tokenizer.vocab_size,
    block_size=256,
    n_layer=6,
    n_head=6,
    n_kv_head=2,
    n_embd=384,
    tie_embeddings=True,
)

model = ECISLM(cfg)
_ = model(tf.zeros((1, cfg.block_size), dtype=tf.int32))
_ = load_checkpoint(checkpoint_dir=CKPT_DIR, step=STEP, model=model, optimizer=None)

print(f"Loaded step {STEP} from {CKPT_DIR}\n")

def run(prompt, is_qa=True):
    if is_qa:
        full = f"User: {prompt}\nAssistant: "
    else:
        full = prompt  # continuation mode (no chat format)

    input_ids = tokenizer.encode(full)
    x = tf.constant([input_ids], dtype=tf.int32)

    y = model.generate(
        idx=x,
        max_new_tokens=MAX_TOKENS,
        temperature=TEMPERATURE,
        top_k=TOP_K,
    ).numpy()[0].tolist()

    text = tokenizer.decode(y[len(input_ids):])

    for marker in ["\nUser:", "<END>"]:
        pos = text.find(marker)
        if pos != -1:
            text = text[:pos]

    return text.strip()

# ---- RUN QA ----
print("=== QA MODE ===\n")
for i, prompt in enumerate(QA_PROMPTS, 1):
    out = run(prompt, is_qa=True)
    print(f"[QA {i}] {prompt}")
    print(f"→ {out}")
    print("-" * 80)

# ---- RUN CONTINUATION ----
print("\n=== CONTINUATION MODE ===\n")
for i, prompt in enumerate(CONTINUATION_PROMPTS, 1):
    out = run(prompt, is_qa=False)
    print(f"[CONT {i}] {prompt}")
    print(f"→ {out}")
    print("-" * 80)
# Out:
# Loaded tokenizer: /kaggle/input/datasets/omarrakhe/12k-run-ouptut/eci-slm/artifact/eci_slm_tokenizer.model
# Loaded step 1650 from /kaggle/working/checkpoints_sft
#
# === QA MODE ===
#
# [QA 1]
#     User: Can nomination papers be sent by email?
# Assistant: No. Nomination papers must be submitted physically to the Returning Officer.
#
# User: Who can submit a nomination paper?
# Assistant:Can nomination papers be sent by email?
# → No. The nomination paper shall be issued by the candidate in the nomination paper. The candidate has to be nominated by the Returning Officer in accordance with the form of nomination paper. The affidavit is a candidate and is not a candidate, as an elector is required to make a nomination paper in the nomination paper. The nomination paper shall not be obtained from the Returning Officer for the purpose
# --------------------------------------------------------------------------------
# [QA 2] Who can submit a nomination paper?
# ...

# %%
import tensorflow as tf
from src.tokenizer import Tokenizer
from src.slm import ECISLM, SLMConfig
from src.checkpoint import load_checkpoint
from pathlib import Path

# ---- paths ----
REPO_ROOT = Path.cwd()
if not (REPO_ROOT / "main.py").exists():
    candidate = Path("/kaggle/working/eci-slm")
    if (candidate / "main.py").exists():
        REPO_ROOT = candidate

CKPT_DIR = Path("/kaggle/working/checkpoints_sft")
if not CKPT_DIR.exists():
    CKPT_DIR = Path("/kaggle/working/checkpoints")

TOKENIZER_PATH = REPO_ROOT / "artifact" / "eci_slm_tokenizer.model"
STEP = int((CKPT_DIR / "best_step.txt").read_text().strip())

MAX_TOKENS = 80

# ---- BEST CONFIG ----
TEMPERATURE = 0.5
TOP_K = 10

# ---- FEW-SHOT PREFIX ----
FEWSHOT_PREFIX = """User: Can nomination papers be sent by email?
Assistant: No. Nomination papers must be submitted physically to the Returning Officer.

User: Who can submit a nomination paper?
Assistant:"""

# ---- PROMPTS ----
QA_PROMPTS = [
    "Can nomination papers be sent by email?",
    "Who can submit a nomination paper?",
    "What happens if nomination papers are incomplete?",
]

CONTINUATION_PROMPTS = [
    "Nomination papers must be filed",
    "The Returning Officer shall",
    "If a candidate fails to submit required documents",
]

# ---- load ----
tokenizer = Tokenizer(TOKENIZER_PATH)

cfg = SLMConfig(
    vocab_size=tokenizer.vocab_size,
    block_size=256,
    n_layer=6,
    n_head=6,
    n_kv_head=2,
    n_embd=384,
    tie_embeddings=True,
)

model = ECISLM(cfg)
_ = model(tf.zeros((1, cfg.block_size), dtype=tf.int32))
_ = load_checkpoint(checkpoint_dir=CKPT_DIR, step=STEP, model=model, optimizer=None)

print(f"Loaded step {STEP} from {CKPT_DIR}\n")

def run(prompt, is_qa=True, fewshot=False):
    if is_qa:
        if fewshot:
            full = FEWSHOT_PREFIX + " " + prompt + "\nAssistant: "
        else:
            full = f"User: {prompt}\nAssistant: "
    else:
        full = prompt  # continuation mode

    input_ids = tokenizer.encode(full)
    x = tf.constant([input_ids], dtype=tf.int32)

    y = model.generate(
        idx=x,
        max_new_tokens=MAX_TOKENS,
        temperature=TEMPERATURE,
        top_k=TOP_K,
    ).numpy()[0].tolist()

    text = tokenizer.decode(y[len(input_ids):])

    for marker in ["\nUser:", "<END>"]:
        pos = text.find(marker)
        if pos != -1:
            text = text[:pos]

    return text.strip()

# ---- RUN QA (no few-shot) ----
print("=== QA MODE (NO FEWSHOT) ===\n")
for i, prompt in enumerate(QA_PROMPTS, 1):
    out = run(prompt, is_qa=True, fewshot=False)
    print(f"[QA {i}] {prompt}")
    print(f"→ {out}")
    print("-" * 80)

# ---- RUN QA (few-shot) ----
print("\n=== QA MODE (WITH FEWSHOT) ===\n")
for i, prompt in enumerate(QA_PROMPTS, 1):
    out = run(prompt, is_qa=True, fewshot=True)
    print(f"[QA-FS {i}] {prompt}")
    print(f"→ {out}")
    print("-" * 80)

# ---- RUN CONTINUATION ----
print("\n=== CONTINUATION MODE ===\n")
for i, prompt in enumerate(CONTINUATION_PROMPTS, 1):
    out = run(prompt, is_qa=False)
    print(f"[CONT {i}] {prompt}")
    print(f"→ {out}")
    print("-" * 80)
# Out:
# Loaded tokenizer: /kaggle/input/datasets/omarrakhe/12k-run-ouptut/eci-slm/artifact/eci_slm_tokenizer.model
# Loaded step 1650 from /kaggle/working/checkpoints_sft
#
# === QA MODE (NO FEWSHOT) ===
#
# [QA 1] Can nomination papers be sent by email?
# → No. The nomination paper has to be rejected by the candidate at any time from the date on which he has been filed. The nomination paper can be filed with the nomination paper. The nomination paper shall be filed by the Returning Officer for scrutiny of nomination papers. The nomination paper of the candidate has been duly duly filed by the candidate and the candidate is not permitted to vote at any
# --------------------------------------------------------------------------------
# [QA 2] Who can submit a nomination paper?
# ...

# %%
import tensorflow as tf
from src.tokenizer import Tokenizer
from src.slm import ECISLM, SLMConfig
from src.checkpoint import load_checkpoint
from pathlib import Path

# ---- paths ----
REPO_ROOT = Path.cwd()
if not (REPO_ROOT / "main.py").exists():
    candidate = Path("/kaggle/working/eci-slm")
    if (candidate / "main.py").exists():
        REPO_ROOT = candidate

CKPT_DIR = Path("/kaggle/input/datasets/omarrakhe/12k-run-ouptut/checkpoints")
STEP = 10600

TOKENIZER_PATH = REPO_ROOT / "artifact" / "eci_slm_tokenizer.model"

MAX_TOKENS = 120

# ---- config ----
TEMPERATURE = 0.6
TOP_K = 30

# ---- prompts (continuation only) ----
PROMPTS = [
    "Nomination papers must be filed",
    "The Returning Officer shall",
    "If a candidate fails to submit required documents",
    "The scrutiny of nomination papers involves",
    "A candidate is disqualified if",
    "During elections, the Election Commission ensures",
]

# ---- load ----
tokenizer = Tokenizer(TOKENIZER_PATH)

cfg = SLMConfig(
    vocab_size=tokenizer.vocab_size,
    block_size=256,
    n_layer=6,
    n_head=6,
    n_kv_head=2,
    n_embd=384,
    tie_embeddings=True,
)

model = ECISLM(cfg)
_ = model(tf.zeros((1, cfg.block_size), dtype=tf.int32))

_ = load_checkpoint(
    checkpoint_dir=CKPT_DIR,
    step=STEP,
    model=model,
    optimizer=None
)

print(f"Loaded PRETRAIN step {STEP} from {CKPT_DIR}\n")

def run(prompt):
    input_ids = tokenizer.encode(prompt)
    x = tf.constant([input_ids], dtype=tf.int32)

    y = model.generate(
        idx=x,
        max_new_tokens=MAX_TOKENS,
        temperature=TEMPERATURE,
        top_k=TOP_K,
    ).numpy()[0].tolist()

    text = tokenizer.decode(y[len(input_ids):])

    for marker in ["\nUser:", "<END>"]:
        pos = text.find(marker)
        if pos != -1:
            text = text[:pos]

    return text.strip()

# ---- run ----
for i, prompt in enumerate(PROMPTS, 1):
    out = run(prompt)
    print(f"[CONT {i}] {prompt}")
    print(f"→ {out}")
    print("-" * 80)
# Out:
# Loaded tokenizer: /kaggle/input/datasets/omarrakhe/12k-run-ouptut/eci-slm/artifact/eci_slm_tokenizer.model
# Loaded PRETRAIN step 10600 from /kaggle/input/datasets/omarrakhe/12k-run-ouptut/checkpoints
#
# [CONT 1] Nomination papers must be filed
# → by the Commission. A copy of such certificate shall be given in the relevant order and the Returning Officer shall also be issued to the Commission’s instructions on the date of poll. Such arrangements should be provided for the purpose. The Commission has to ensure that the candidates/RO are given to the Returning Officer for the purpose of counting of votes in the constituency and in the context of such election. The Commission may also be the case of the candidate and his/her vote in the constituency. The Commission has to be kept in the constituency as they are in the presence of the candidates and their representatives.
# --------------------------------------------------------------------------------
# ...

# %%
# !python src/eval.py \
  --repo-root /kaggle/input/datasets/omarrakhe/12k-run-ouptut/eci-slm \
  --checkpoint-dir /kaggle/input/datasets/omarrakhe/12k-run-ouptut/checkpoints \
  --step 10600 \
  --tokenizer-path /kaggle/input/datasets/omarrakhe/12k-run-ouptut/eci-slm/artifact/eci_slm_tokenizer.model \
  --output-dir /kaggle/working/results_pretrain \
  --device auto \
  --precision mixed_fp16 \
  --block-size 256 \
  --n-layer 6 \
  --n-head 6 \
  --n-kv-head 2 \
  --n-embd 384
# Out:
# 2026-03-29 14:19:20.586158: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774793960.962101     161 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774793961.066832     161 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774793962.000274     161 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
